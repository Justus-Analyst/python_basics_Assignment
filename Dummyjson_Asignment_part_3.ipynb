# %%
import requests

product_url = "https://dummyjson.com/products"

products_data = requests.get(product_url)

products_data.status_code

dummy_product_data = products_data.json()


dummy_product_data

type (dummy_product_data)
# Out:
# dict

# %%
#Convert the extracted json_products_dummy data into a well-structured DataFrame

import pandas
products_db = pandas.DataFrame(dummy_product_data)

#Save the final output as a well-structured CSV file
products_db = products_db.to_csv("products_db.csv", index = False)
