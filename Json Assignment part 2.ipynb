# %%
import requests

url = "https://raw.githubusercontent.com/Justus-Analyst/python_basics_Assignment/refs/heads/main/school_db.json"

school_db = requests.get(url)

updated_school_db = school_db.json()
updated_school_db


school_db.status_code

school_db.json()

type(updated_school_db)
# Out:
# list

# %%
#Convert the extracted JSON data into a well-structured DataFrame
import pandas
new_school_db = pandas.DataFrame(updated_school_db)

#Save the final output as a well-structured CSV file
new_school_db = new_school_db.to_csv("school_db.csv", index = False)
